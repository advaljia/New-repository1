# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
res = requests.get(url)
res = res.text.encode(res.encoding).decode('utf-8')
soup = BeautifulSoup(res,'html.parser')

# %%
l1 = []
l2 = []
l3 = []

# %%
a = 0
for item in soup.tbody.find_all("td"): 
	a += 1
	item.get_text()
	if a == 1:
		l1.append(item.get_text().strip())
	elif a == 2:
		l2.append(item.get_text().strip())
	else :
		l3.append(item.get_text().strip())
		a -= 3

# %%
table1 ={'Postcode':l1,'Borough':l2,'Neighbourhood':l3}
dftable = pd.DataFrame(table1)
dftable.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
l31 =[]
for i in l3: 
  l31.append(i.strip())

# %%
table1 ={'Postcode':l1,'Borough':l2,'Neighbourhood':l31}
dftable = pd.DataFrame(table1)
dftable.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
dftable2 = dftable[dftable['Borough']!='Not assigned']
dftable3 = dftable2[dftable2['Neighbourhood']!='Not assigned']
dftable3.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M6A        North York  Lawrence Heights
# 6      M6A        North York    Lawrence Manor

# %%
dfsp = pd.Series(dftable3['Postcode'])
dfsp.unique()
# Out:
# array(['M3A', 'M4A', 'M5A', 'M6A', 'M7A', 'M1B', 'M3B', 'M4B', 'M5B',
#        'M6B', 'M9B', 'M1C', 'M3C', 'M4C', 'M5C', 'M6C', 'M9C', 'M1E',
#        'M4E', 'M5E', 'M6E', 'M1G', 'M4G', 'M5G', 'M6G', 'M1H', 'M2H',
#        'M3H', 'M4H', 'M5H', 'M6H', 'M1J', 'M2J', 'M3J', 'M4J', 'M5J',
#        'M6J', 'M1K', 'M2K', 'M3K', 'M4K', 'M5K', 'M6K', 'M1L', 'M2L',
#        'M3L', 'M4L', 'M5L', 'M6L', 'M9L', 'M1M', 'M2M', 'M3M', 'M4M',
#        'M5M', 'M6M', 'M9M', 'M1N', 'M2N', 'M3N', 'M4N', 'M5N', 'M6N',
#        'M9N', 'M1P', 'M2P', 'M4P', 'M5P', 'M6P', 'M9P', 'M1R', 'M2R',
#        'M4R', 'M5R', 'M6R', 'M7R', 'M9R', 'M1S', 'M4S', 'M5S', 'M6S',
#        'M1T', 'M4T', 'M5T', 'M1V', 'M4V', 'M5V', 'M8V', 'M9V', 'M1W',
#        'M4W', 'M5W', 'M8W', 'M9W', 'M1X', 'M4X', 'M5X', 'M8X', 'M4Y',
#        'M7Y', 'M8Y', 'M8Z'], dtype=object)

# %%
lnei = []
for i in dfsp.unique():
  lnei.append(','.join(pd.Series(dftable3[dftable['Postcode']==i]['Neighbourhood']).unique().tolist()))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
lpos = dfsp.unique().tolist()

# %%
lbor = []
for i in dfsp.unique():
  lbor.append(''.join(pd.Series(dftable3[dftable['Postcode']==i]['Borough']).unique().tolist()))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
table2 ={'Postcode':lpos,'Borough':lbor,'Neighbourhood':lnei}
dftablen2 = pd.DataFrame(table2)
dftablen2
# Out:
#     Postcode  ...                                      Neighbourhood
# 0        M3A  ...                                          Parkwoods
# 1        M4A  ...                                   Victoria Village
# 2        M5A  ...                                       Harbourfront
# 3        M6A  ...                    Lawrence Heights,Lawrence Manor
# 4        M7A  ...                                       Queen's Park
# ..       ...  ...                                                ...
# 97       M8X  ...        The Kingsway,Montgomery Road,Old Mill North
# 98       M4Y  ...                               Church and Wellesley
# 99       M7Y  ...  Business Reply Mail Processing Centre 969 Eastern
# 100      M8Y  ...  Humber Bay,King's Mill Park,Kingsway Park Sout...
# 101      M8Z  ...  Kingsway Park South West,Mimico NW,The Queensw...
#
# [102 rows x 3 columns]

# %%
dftablen2.head(12)
# Out:
#    Postcode  ...                                      Neighbourhood
# 0       M3A  ...                                          Parkwoods
# 1       M4A  ...                                   Victoria Village
# 2       M5A  ...                                       Harbourfront
# 3       M6A  ...                    Lawrence Heights,Lawrence Manor
# 4       M7A  ...                                       Queen's Park
# 5       M1B  ...                                      Rouge,Malvern
# 6       M3B  ...                                    Don Mills North
# 7       M4B  ...                     Woodbine Gardens,Parkview Hill
# 8       M5B  ...                            Ryerson,Garden District
# 9       M6B  ...                                          Glencairn
# 10      M9B  ...  Cloverdale,Islington,Martin Grove,Princess Gar...
# 11      M1C  ...               Highland Creek,Rouge Hill,Port Union
#
# [12 rows x 3 columns]

# %%
# !pip install wget
import wget
url = 'http://cocl.us/Geospatial_data'
wget.download(url)
# Out:
# ...
#   Created wheel for wget: filename=wget-3.2-cp36-none-any.whl size=9682 sha256=3e774a893a7735ebfb668d5baa95e144f105c228dd37013f3d46a40c6c6f7603
#   Stored in directory: /root/.cache/pip/wheels/40/15/30/7d8f7cea2902b4db79e3fea550d7d7b85ecb27ef992b618f3f
# Successfully built wget
# ...
# 'Geospatial_Coordinates.csv'

# %%
geodata = pd.read_csv('Geospatial_Coordinates.csv')

# %%
geodata.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
lat = []
lon = []
for i in dfsp.unique():
  lat.append(geodata[geodata['Postal Code']==i]['Latitude'].values[0])
  lon.append(geodata[geodata['Postal Code']==i]['Longitude'].values[0])

# %%
table3 ={'Postcode':lpos,'Borough':lbor,'Neighbourhood':lnei,'Latitude':lat,'Longitude':lon}
dftablen3 = pd.DataFrame(table3)
dftablen3.head(12)
# Out:
#    Postcode           Borough  ...   Latitude  Longitude
# 0       M3A        North York  ...  43.753259 -79.329656
# 1       M4A        North York  ...  43.725882 -79.315572
# 2       M5A  Downtown Toronto  ...  43.654260 -79.360636
# 3       M6A        North York  ...  43.718518 -79.464763
# 4       M7A  Downtown Toronto  ...  43.662301 -79.389494
# 5       M1B       Scarborough  ...  43.806686 -79.194353
# 6       M3B        North York  ...  43.745906 -79.352188
# 7       M4B         East York  ...  43.706397 -79.309937
# 8       M5B  Downtown Toronto  ...  43.657162 -79.378937
# 9       M6B        North York  ...  43.709577 -79.445073
# 10      M9B         Etobicoke  ...  43.650943 -79.554724
# 11      M1C       Scarborough  ...  43.784535 -79.160497
#
# [12 rows x 5 columns]

# %%
from geopy.geocoders import Nominatim
import folium

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# %%
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10)
for lat, lng, borough, neighborhood in zip(dftablen3['Latitude'], dftablen3['Longitude'], dftablen3['Borough'], dftablen3['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            500, 
            LIMIT)
            
results = requests.get(url).json()["response"]['groups'][0]['items']

# %%
CLIENT_ID = '13FABADQC44J00VQPRA4TXEMETZC5UE0KX412OGQICYVWKE4'
CLIENT_SECRET = 'IZ0KQON3EPG55FZ1UKWBXPVGH4UQHOPH3PQEWTJPEFPWP5BI'
VERSION = '20180605'
LIMIT = 100

# %%
toronto_venues = getNearbyVenues(names=dftablen3['Neighbourhood'],
                                   latitudes=dftablen3['Latitude'],
                                   longitudes=dftablen3['Longitude']
                                  )
# Out:
# Parkwoods
# Victoria Village
# Harbourfront
# Lawrence Heights,Lawrence Manor
# Queen's Park
# Rouge,Malvern
# Don Mills North
# Woodbine Gardens,Parkview Hill
# Ryerson,Garden District
# Glencairn
# Cloverdale,Islington,Martin Grove,Princess Gardens,West Deane Park
# Highland Creek,Rouge Hill,Port Union
# Flemingdon Park,Don Mills South
# Woodbine Heights
# St. James Town
# Humewood-Cedarvale
# Bloordale Gardens,Eringate,Markland Wood,Old Burnhamthorpe
# Guildwood,Morningside,West Hill
# The Beaches
# Berczy Park
# Caledonia-Fairbanks
# Woburn
# Leaside
# Central Bay Street
# Christie
# Cedarbrae
# Hillcrest Village
# Bathurst Manor,Downsview North,Wilson Heights
# Thorncliffe Park
# Adelaide,King,Richmond
# Dovercourt Village,Dufferin
# Scarborough Village
# Fairview,Henry Farm,Oriole
# Northwood Park,York University
# East Toronto
# Harbourfront East,Toronto Islands,Union Station
# Little Portugal,Trinity
# East Birchmount Park,Ionview,Kennedy Park
# Bayview Village
# ...

# %%
toronto_venues
# Out:
#                                            Neighborhood  ...          Venue Category
# 0                                             Parkwoods  ...                    Park
# 1                                             Parkwoods  ...    Fast Food Restaurant
# 2                                             Parkwoods  ...       Food & Drink Shop
# 3                                             Parkwoods  ...                Bus Stop
# 4                                      Victoria Village  ...            Hockey Arena
# ...                                                 ...  ...                     ...
# 2231  Kingsway Park South West,Mimico NW,The Queensw...  ...             Social Club
# 2232  Kingsway Park South West,Mimico NW,The Queensw...  ...             Flower Shop
# 2233  Kingsway Park South West,Mimico NW,The Queensw...  ...  Thrift / Vintage Store
# 2234  Kingsway Park South West,Mimico NW,The Queensw...  ...                     Gym
# ...

# %%
toronto_restaurant = toronto_venues[toronto_venues['Venue Category'].str.contains('Restaurant' or 'Food')]
toronto_restaurant.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  ...  Venue Category
# Neighborhood                                                               ...
# Adelaide,King,Richmond                                                 29  ...              29
# Agincourt                                                               2  ...               2
# Albion Gardens,Beaumond Heights,Humbergate,Jame...                      1  ...               1
# Bathurst Manor,Downsview North,Wilson Heights                           4  ...               4
# Bayview Village                                                         2  ...               2
# ...                                                                   ...  ...             ...
# Westmount                                                               1  ...               1
# Willowdale South                                                       12  ...              12
# ...

# %%
toronto_restaurant.groupby('Venue Category').count().sort_index(axis=0,ascending=False,by='Neighborhood')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)
#   """Entry point for launching an IPython kernel.
#                                  Neighborhood  ...  Venue Longitude
# Venue Category                                 ...
# Restaurant                                 66  ...               66
# Italian Restaurant                         50  ...               50
# Japanese Restaurant                        38  ...               38
# American Restaurant                        28  ...               28
# Sushi Restaurant                           26  ...               26
# Thai Restaurant                            26  ...               26
# Fast Food Restaurant                       25  ...               25
# Seafood Restaurant                         25  ...               25
# Chinese Restaurant                         23  ...               23
# ...

# %%
toronto_restaurant.groupby('Venue Category').count()
toronto_onehot = pd.get_dummies(toronto_restaurant[['Venue Category']], prefix="", prefix_sep="").reset_index()
toronto_onehot
toronto_onehot['Neighborhood'] = toronto_restaurant['Neighborhood']

# %%
toronto_onehot['Neighborhood'] = toronto_restaurant.reset_index()['Neighborhood']
toronto_onehot['Neighborhood']
# Out:
# 0                                              Parkwoods
# 1                                       Victoria Village
# 2                                       Victoria Village
# 3                                           Harbourfront
# 4                                           Harbourfront
#                              ...
# 504                                 Church and Wellesley
# 505                                 Church and Wellesley
# 506    Business Reply Mail Processing Centre 969 Eastern
# 507    Business Reply Mail Processing Centre 969 Eastern
# 508    Kingsway Park South West,Mimico NW,The Queensw...
# Name: Neighborhood, Length: 509, dtype: object

# %%
toronto_onehot.drop('Neighborhood', axis = 1)
# Out:
#      index  ...  Vietnamese Restaurant
# 0        1  ...                      0
# 1        6  ...                      0
# 2        7  ...                      0
# 3       13  ...                      0
# 4       29  ...                      0
# ..     ...  ...                    ...
# 504   2194  ...                      0
# 505   2197  ...                      0
# 506   2209  ...                      0
# 507   2210  ...                      0
# 508   2228  ...                      0
#
# [509 rows x 48 columns]

# %%
toronto_venues['Neighborhood Latitude'][toronto_venues['Neighborhood']== 'Berczy Park'].values.tolist()[0]
# Out:
# 43.644770799999996

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

# %%
lat1 = []
lon1 = []
for i in toronto_grouped['Neighborhood']:
  a = toronto_venues['Neighborhood Latitude'][toronto_venues['Neighborhood']== i].values.tolist()[0]
  b = toronto_venues['Neighborhood Longitude'][toronto_venues['Neighborhood']== i].values.tolist()[0]
  lat1.append(a)
  lon1.append(b)

# %%
toronto_grouped.insert(0, 'Latitude', lat1)
toronto_grouped.insert(0, 'Longitude', lon1)
toronto_grouped
# Out:
#     Longitude   Latitude  ... Vegetarian / Vegan Restaurant  Vietnamese Restaurant
# 0  -79.384568  43.650571  ...                      0.068966               0.000000
# 1  -79.262029  43.794200  ...                      0.000000               0.000000
# 2  -79.588437  43.739416  ...                      0.000000               0.000000
# 3  -79.442259  43.754328  ...                      0.000000               0.000000
# 4  -79.385975  43.786947  ...                      0.000000               0.000000
# ..        ...        ...  ...                           ...                    ...
# 62 -79.532242  43.696319  ...                      0.000000               0.000000
# 63 -79.408493  43.770120  ...                      0.000000               0.083333
# 64 -79.216917  43.770992  ...                      0.000000               0.000000
# 65 -79.309937  43.706397  ...                      0.000000               0.000000
# ...

# %%
toronto_grouped
# Out:
#     Cluster Labels  ... Vietnamese Restaurant
# 0                1  ...              0.083333
# 1                1  ...              0.090909
# 2                0  ...              0.000000
# 3                1  ...              0.000000
# 4                0  ...              0.000000
# 5                0  ...              0.000000
# 6                1  ...              0.000000
# 7                0  ...              0.000000
# 8                1  ...              0.000000
# 9                3  ...              0.000000
# 10               1  ...              0.000000
# 11               4  ...              0.000000
# 12               1  ...              0.045455
# 13               1  ...              0.000000
# 14               1  ...              0.000000
# 15               1  ...              0.000000
# 16               2  ...              0.000000
# 17               1  ...              0.000000
#
# [18 rows x 49 columns]

# %%
from sklearn.cluster import KMeans

kclusters = 8

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 6, 0, 2, 6, 2, 2, 2, 3, 2], dtype=int32)

# %%
toronto_grouped.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
toronto_grouped = toronto_grouped.drop('Cluster Labels', axis = 1)

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_grouped['Latitude'], toronto_grouped['Longitude'], toronto_grouped['Neighborhood'], toronto_grouped['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster-1)],
        fill=True,
        fill_color=rainbow[int(cluster-1)],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
toronto_grouped.head()
# Out:
#    Cluster Labels  ...  Vietnamese Restaurant
# 0               2  ...                    0.0
# 1               6  ...                    0.0
# 2               0  ...                    0.0
# 3               2  ...                    0.0
# 4               6  ...                    0.0
#
# [5 rows x 51 columns]

# %%
toronto_g2 = toronto_grouped.drop('Cluster Labels',axis = 1)
toronto_g2 = toronto_g2.drop('Longitude',axis = 1)
toronto_g2 = toronto_g2.drop('Latitude',axis = 1)

# %%
num_top_venues = 5

for hood in toronto_g2['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_g2[toronto_g2['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Adelaide,King,Richmond----
#                            venue  freq
# 0                Thai Restaurant  0.14
# 1               Sushi Restaurant  0.10
# 2                     Restaurant  0.10
# 3               Asian Restaurant  0.07
# 4  Vegetarian / Vegan Restaurant  0.07
#
#
# ----Agincourt----
#                        venue  freq
# 0  Latin American Restaurant   0.5
# 1         Chinese Restaurant   0.5
# 2          Afghan Restaurant   0.0
# 3    New American Restaurant   0.0
# 4         Italian Restaurant   0.0
#
#
# ----Albion Gardens,Beaumond Heights,Humbergate,Jamestown,Mount Olive,Silverstone,South Steeles,Thistletown----
#                   venue  freq
# 0  Fast Food Restaurant   1.0
# 1     Afghan Restaurant   0.0
# 2     Indian Restaurant   0.0
# 3    Italian Restaurant   0.0
# 4   Japanese Restaurant   0.0
#
#
# ----Bathurst Manor,Downsview North,Wilson Heights----
#                        venue  freq
# 0           Sushi Restaurant  0.25
# ...

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Restaurant'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Restaurant'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_g2['Neighborhood']

for ind in np.arange(toronto_g2.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_g2.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood  ... 10th Most Common Restaurant
# 0                             Adelaide,King,Richmond  ...    Mediterranean Restaurant
# 1                                          Agincourt  ...        Ethiopian Restaurant
# 2  Albion Gardens,Beaumond Heights,Humbergate,Jam...  ...         Dumpling Restaurant
# 3      Bathurst Manor,Downsview North,Wilson Heights  ...        Ethiopian Restaurant
# 4                                    Bayview Village  ...        Ethiopian Restaurant
#
# [5 rows x 11 columns]

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
neighborhoods_venues_sorted[neighborhoods_venues_sorted['Cluster Labels'] == 0]
# Out:
#     Cluster Labels  ... 10th Most Common Restaurant
# 2                0  ...         Dumpling Restaurant
# 38               0  ...         Dumpling Restaurant
# 48               0  ...         Dumpling Restaurant
# 50               0  ...         Dumpling Restaurant
# 65               0  ...         Dumpling Restaurant
#
# [5 rows x 12 columns]
